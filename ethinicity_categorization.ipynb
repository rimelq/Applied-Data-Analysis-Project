# %% [markdown]
# ### Data Loading and preprocessing

# %%
# %matplotlib inline
import os
import pandas as pd
import requests
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data

characters = pd.read_csv('./data/character.metadata.tsv', sep='\t', 
                         names=['wiki_movie_id', 'free_movie_id', 'release', 'char_name', 'actor_birth', 'actor_gender', 'actor_height',
                                 'actor_ethnicity', 'actor_name', 'age_at_release', 'free_map_id', 'free_char_id', 'free_actor_id'] )
movies = pd.read_csv('./data/movie.metadata.tsv', sep='\t', names=['wiki_movie_id', 'free_movie_id', 'movie_name', 'release', 
                                                                   'box_office', 'runtime', 'languages', 'countries', 'genres'])
summaries = df = pd.read_csv('./data/plot_summaries.txt', delimiter='\t', header=None, names=['movie_id', 'plot_summary'], encoding='utf-8')

# %%
print(characters.shape)
print(movies['movie_name'].nunique())
print(summaries.shape)
# Out:
# (439466, 12)
# 69247
# (42303, 2)

# %% [markdown]
# #### Data exploration

# %%
characters.head()
# Out:
#    wiki_movie_id free_movie_id     release                   char_name  \
# 0         975900     /m/03vyhn  2001-08-24                    Akooshay
# 1         975900     /m/03vyhn  2001-08-24  Lieutenant Melanie Ballard
# 2         975900     /m/03vyhn  2001-08-24         Desolation Williams
# 3         975900     /m/03vyhn  2001-08-24          Sgt Jericho Butler
# 4         975900     /m/03vyhn  2001-08-24             Bashira Kincaid
#
#   actor_birth actor_gender  actor_height actor_ethnicity          actor_name  \
# 0  1958-08-26            F         1.620             NaN      Wanda De Jesus
# 1  1974-08-15            F         1.780      /m/044038p  Natasha Henstridge
# 2  1969-06-15            M         1.727         /m/0x67            Ice Cube
# 3  1967-09-12            M         1.750             NaN       Jason Statham
# 4  1977-09-25            F         1.650             NaN         Clea DuVall
#
#    age_at_release free_map_id free_char_id free_actor_id
# 0            42.0  /m/0bgchxw   /m/0bgcj3x    /m/03wcfv7
# 1            27.0   /m/0jys3m   /m/0bgchn4     /m/0346l4
# 2            32.0   /m/0jys3g   /m/0bgchn_    /m/01vw26l
# 3            33.0  /m/02vchl6   /m/0bgchnq     /m/034hyc
# 4            23.0  /m/02vbb3r   /m/0bgchp9     /m/01y9xg

# %%
movies.head()
# Out:
#    wiki_movie_id free_movie_id  \
# 0         975900     /m/03vyhn
# 1        3196793     /m/08yl5d
# 2       28463795    /m/0crgdbh
# 3        9363483    /m/0285_cd
# 4         261236     /m/01mrr1
#
#                                           movie_name     release  box_office  \
# 0                                     Ghosts of Mars  2001-08-24  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...  2000-02-16         NaN
# 2                                        Brun bitter        1988         NaN
# 3                                   White Of The Eye        1987         NaN
# 4                                  A Woman in Flames        1983         NaN
#
#    runtime                           languages  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1     95.0  {"/m/02h40lc": "English Language"}
# 2     83.0  {"/m/05f_3": "Norwegian Language"}
# 3    110.0  {"/m/02h40lc": "English Language"}
# 4    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
# Standardize 'release' column to only keep the year
def extract_year(release_date):
    try:
        # Attempt to convert to datetime and extract the year
        year = pd.to_datetime(release_date, errors='coerce').year
        if pd.notna(year):
            return year
        # If conversion fails, try extracting just the first 4 digits as year
        return int(str(release_date)[:4])
    except:
        return None

movies['release'] = movies['release'].apply(extract_year)
movies.head()
# Out:
#    wiki_movie_id free_movie_id  \
# 0         975900     /m/03vyhn
# 1        3196793     /m/08yl5d
# 2       28463795    /m/0crgdbh
# 3        9363483    /m/0285_cd
# 4         261236     /m/01mrr1
#
#                                           movie_name  release  box_office  \
# 0                                     Ghosts of Mars   2001.0  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000.0         NaN
# 2                                        Brun bitter   1988.0         NaN
# 3                                   White Of The Eye   1987.0         NaN
# 4                                  A Woman in Flames   1983.0         NaN
#
#    runtime                           languages  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1     95.0  {"/m/02h40lc": "English Language"}
# 2     83.0  {"/m/05f_3": "Norwegian Language"}
# 3    110.0  {"/m/02h40lc": "English Language"}
# 4    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
summaries.head()
# Out:
#    movie_id                                       plot_summary
# 0  23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1  31186339  The nation of Panem consists of a wealthy Capi...
# 2  20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3   2231378  The Lemon Drop Kid , a New York City swindler,...
# 4    595909  Seventh-day Adventist Church pastor Michael Ch...

# %%
print(characters.isnull().sum())
# Out:
# wiki_movie_id           0
# free_movie_id           0
# release              9995
# char_name          257875
# actor_birth        106145
# actor_gender        45609
# actor_height       295845
# actor_ethnicity    344611
# actor_name           1228
# age_at_release     158113
# free_map_id             0
# free_char_id       257865
# free_actor_id         815
# dtype: int64

# %%
print(movies.isnull().sum())
# Out:
# wiki_movie_id        0
# free_movie_id        0
# movie_name           0
# release           6902
# box_office       73340
# runtime          20450
# languages            0
# countries            0
# genres               0
# dtype: int64

# %%
print(summaries.isnull().sum())
# Out:
# movie_id        0
# plot_summary    0
# dtype: int64

# %% [markdown]
# #### Data cleaning

# %%
# drop columns that are non relevant for our analysis 
characters.drop(columns=['char_name'], inplace=True)
characters.drop(columns=['actor_height'], inplace=True)
movies.drop(columns=['runtime'], inplace= True)

# %%
# handling missing values for characters
# dropping them for release, actor_name because non relevant for our analysis
# filling the nans for the others 

characters.dropna(subset=['release'], inplace=True)
characters.dropna(subset=['actor_name'], inplace=True)

characters['actor_birth'] = pd.to_datetime(characters['actor_birth'], errors='coerce')
characters['actor_birth_year'] = characters['actor_birth'].dt.year
characters['actor_birth_year'] = characters['actor_birth_year'].fillna(characters['actor_birth_year'].median())
characters.drop(columns=['actor_birth'], inplace=True)

characters['actor_gender'] = characters['actor_gender'].fillna('Unknown')
characters['actor_ethnicity'] = characters['actor_ethnicity'].fillna('Unknown')
characters['age_at_release'] = characters['age_at_release'].fillna(characters['age_at_release'].median())

# %%
# handling missing values for movies

movies.dropna(subset=['release'], inplace=True)
movies['box_office'] = movies['box_office'].fillna(movies['box_office'].median())
movies.head()
# Out:
#    wiki_movie_id free_movie_id  \
# 0         975900     /m/03vyhn
# 1        3196793     /m/08yl5d
# 2       28463795    /m/0crgdbh
# 3        9363483    /m/0285_cd
# 4         261236     /m/01mrr1
#
#                                           movie_name  release  box_office  \
# 0                                     Ghosts of Mars   2001.0  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000.0  10809846.5
# 2                                        Brun bitter   1988.0  10809846.5
# 3                                   White Of The Eye   1987.0  10809846.5
# 4                                  A Woman in Flames   1983.0  10809846.5
#
#                             languages  \
# 0  {"/m/02h40lc": "English Language"}
# 1  {"/m/02h40lc": "English Language"}
# 2  {"/m/05f_3": "Norwegian Language"}
# 3  {"/m/02h40lc": "English Language"}
# 4   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %% [markdown]
# #### Merging data

# %% [markdown]
# #### Ethnicity categorization

# %%
# Extract and print unique ethnicities from the `characters` DataFrame
unique_ethnicities = characters['actor_ethnicity'].unique()
print(', '.join([f'\'{ethnicity}\'' for ethnicity in unique_ethnicities]))
# Out:
# 'Unknown', '/m/044038p', '/m/0x67', '/m/064b9n', '/m/041rx', '/m/033tf_', '/m/04gfy7', '/m/0222qb', '/m/01qhm_', '/m/0dryh9k', '/m/048sp5', '/m/04mvp8', '/m/0bzkm2', '/m/02p1pl6', '/m/0bjbszh', '/m/022fdt', '/m/0cqgdq', '/m/0ffkb4', '/m/075dhf0', '/m/01hwt', '/m/0xnvg', '/m/0dqqwy', '/m/048z7l', '/m/07bch9', '/m/09v5bdn', '/m/02w7gg', '/m/03bkbh', '/m/02vsw1', '/m/09kr66', '/m/09vc4s', '/m/0g0x7_', '/m/042gtr', '/m/0cm7w1', '/m/046cwm', '/m/04dbw3', '/m/02ctzb', '/m/0g8_vp', '/m/092h2qt', '/m/0g6ff', '/m/0278pqj', '/m/0301y_', '/m/019kn7', '/m/0cnvdq1', '/m/03295l', '/m/065b6q', '/m/03pqwy', '/m/01xhh5', '/m/03ts0c', '/m/06gbnc', '/m/07hwkr', '/m/0bpjh3', '/m/0fpjs3j', '/m/04nrnz', '/m/09k5jvk', '/m/07mqps', '/m/08hpk0', '/m/03ttfc', '/m/0d9q7j', '/m/075_n6', '/m/0dllcfn', '/m/04kbvpz', '/m/03ftx7', '/m/0747611', '/m/025rpb0', '/m/06mvq', '/m/047l_90', '/m/029f2r', '/m/01rv7x', '/m/05sf2x', '/m/01336l', '/m/0bh91q8', '/m/01g7zj', '/m/0cn68', '/m/02sch9', '/m/0fqp6zk', '/m/02y_9mh', '/m/0d7wh', '/m/0g96wd', '/m/047948f', '/m/04ggbzy', '/m/04q7gbh', '/m/013xrm', '/m/0gkxl2', '/m/0dbxy', '/m/0cmdl5l', '/m/0268d21', '/m/0912ll', '/m/022dp5', '/m/019lrz', '/m/03bx0k4', '/m/02p_gby', '/m/012c1l', '/m/04y29', '/m/09743', '/m/03w9bjf', '/m/09m6hr', '/m/0583cz', '/m/02g7
m/03ty8_', '/m/02rdfpy', '/m/03fvrb', '/m/04pnf', '/m/0bvjpj', '/m/039z49', '/m/01_5cg', '/m/01ywdy', '/m/03q819', '/m/025xss1', '/m/0c29q8', '/m/013s41', '/m/03x1x', '/m/05cc9h', '/m/03m9my8', '/m/0165md', '/m/0g44f5', '/m/0gtwjz6', '/m/01hm_', '/m/03zcwh', '/m/0bns36b', '/m/04lgl9t', '/m/0g5k7qv', '/m/067lv3', '/m/0ftlzz', '/m/02r11hz', '/m/06y24j', '/m/02m0kh', '/m/01l0ty', '/m/03cmqbt', '/m/0g5rkt4', '/m/02dd5z', '/m/01gr8h', '/m/01vr3v', '/m/09g34_', '/m/09cd0m', '/m/03h11s3', '/m/05ms3p0', '/m/04lfc70', '/m/06dy2k', '/m/013z8m', '/m/0ftwg', '/m/0fk55', '/m/06bkf', '/m/0c_lbq', '/m/0301xt', '/m/01kb9y', '/m/042199j', '/m/03m3p6w', '/m/0br_9j', '/m/032m0b', '/m/05y2yj', '/m/01f9bg', '/m/04hqxn', '/m/068y7m', '/m/0ffk5n', '/m/03gy1h2', '/m/04wysy', '/m/04fh1b', '/m/02vys3l', '/m/044bp_', '/m/0dtkkb', '/m/0fp4n', '/m/0166vx', '/m/047q05d', '/m/0c50f', '/m/01srl7', '/m/0fpxlz9', '/m/03lnnd', '/m/02pj9yr', '/m/04118b', '/m/0xff', '/m/0bdynxs', '/m/01gby2', '/m/0dn1_0', '/m/062szv5', '/m/062zk4r', '/m/0960kn',
                 '/m/043_z22', '/m/097r55', '/m/035b50', '/m/01hphz', '/m/033fjj', '/m/0b3zsn', '/m/04lhnps', '/m/08c25t', '/m/05sng', '/m/05bzpzx', '/m/064rb5l', '/m/01km_m', '/m/059v8', '/m/03b_13l', '/m/09c8kp', '/m/05ztd1', '/m/04c28', '/m/0463n9y', '/m/04jtjvt', '/m/01h4n', '/m/03hjx6f', '/m/027936c', '/m/06w4lv', '/m/03nvq', '/m/03nz70', '/m/01g3rx', '/m/02wz7j', '/m/04kdwcx', '/m/04_8lfc', '/m/033qt1', '/m/08j1fb', '/m/07wsyr', '/m/06vb7b', '/m/012fh', '/m/0dm3xpw', '/m/09r2kh', '/m/02ry8mk', '/m/029q52', '/m/026d074']

# Function to split the list into batches
def split_into_batches(lst, batch_size):
    for i in range(0, len(lst), batch_size):
        yield lst[i:i + batch_size]

# Create an empty dictionary to store the mappings
freebase_to_wikidata_mapping = {}

# Iterate over batches of Freebase IDs
batch_size = 50  # Set batch size to 50 to avoid long URL issues
for batch in split_into_batches(freebase_ids, batch_size):
    # Create a batch SPARQL query
    query = """
    SELECT ?freebase_id ?item ?itemLabel WHERE {
      VALUES ?freebase_id {""" + " ".join([f'"{fb_id}"' for fb_id in batch]) + """}
      # ?item wdt:P646 ?freebase_id.
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }
    """

    # Endpoint for Wikidata SPARQL
    url = "https://query.wikidata.org/sparql"
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "application/json"
    }

    # Send the request to Wikidata
    response = requests.get(url, headers=headers, params={"query": query, "format": "json"})

    # Check the status and response
    if response.status_code == 200:
        data = response.json()
        if 'results' in data and 'bindings' in data['results']:
            for result in data['results']['bindings']:
                freebase_id = result['freebase_id']['value']
                wikidata_id = result['item']['value'].split('/')[-1]
                label = result['itemLabel']['value']
                freebase_to_wikidata_mapping[freebase_id] = {
                    "wikidata_id": wikidata_id,
                    "label": label
                }
        else:
            print("No valid data found in response for this batch.")
    else:
        print(f"Error: Received status code {response.status_code} for batch starting with {batch[0]}")

# Print the dictionary to verify the mapping
print("Mappings successfully retrieved:")
for fb_id, details in freebase_to_wikidata_mapping.items():
    print(f"Freebase ID: {fb_id}, Wikidata ID: {details['wikidata_id']}, Label: {details['label']}")
# Out:
# Mappings successfully retrieved:
# Freebase ID: /m/02vsw1, Wikidata ID: Q43103, Label: European Americans
# Freebase ID: /m/064b9n, Wikidata ID: Q120601, Label: Omaha Tribe of Nebraska
# Freebase ID: /m/01qhm_, Wikidata ID: Q141817, Label: German Americans
# Freebase ID: /m/0bzkm2, Wikidata ID: Q707133, Label: Taiwanese people
# Freebase ID: /m/09kr66, Wikidata ID: Q1140588, Label: Russian Americans
# Freebase ID: /m/046cwm, Wikidata ID: Q1255534, Label: Nair
# Freebase ID: /m/09vc4s, Wikidata ID: Q1344183, Label: English Americans
# Freebase ID: /m/0278pqj, Wikidata ID: Q21999799, Label: British Nigerian
# Freebase ID: /m/03ts0c, Wikidata ID: Q121842, Label: French
# Freebase ID: /m/0301y_, Wikidata ID: Q190168, Label: Yoruba people
# Freebase ID: /m/048z7l, Wikidata ID: Q678551, Label: American Jews
# Freebase ID: /m/033tf_, Wikidata ID: Q1075293, Label: Irish Americans
# Freebase ID: /m/019kn7, Wikidata ID: Q31340083, Label: Q31340083
# Freebase ID: /m/02w7gg, Wikidata ID: Q42406, Label: English people
# Freebase ID: /m/0g6ff, Wikidata ID: Q49542, Label: Russians
# Freebase ID: /m/0ffkb4, Wikidata ID: Q1749358, Label: Lithuanian Americans
# Freebase ID: /m/03pqwy, Wikidata ID: Q3072663, Label: Finnish Americans
# Freebase ID: /m/0222qb, Wikidata ID: Q50001, Label: Italians
# Freebase ID: /m/02ctzb, Wikidata ID: Q235155, Label: White people
# Freebase ID: /m/0cqgdq, Wikidata ID: Q1265028, Label: Marathi people
# Freebase ID: /m/04dbw3, Wikidata ID: Q1790886, Label: Cuban Americans
# Freebase ID: /m/04gfy7, Wikidata ID: Q2643509, Label: Indian Americans
# Freebase ID: /m/0dqqwy, Wikidata ID: Q3015339, Label: Danish Americans
# Freebase ID: /m/01xhh5, Wikidata ID: Q484464, Label: Koreans
# Freebase ID: /m/09v5bdn, Wikidata ID: Q893594, Label: Puerto Ricans
# Freebase ID: /m/048sp5, Wikidata ID: Q3520262, Label: Ezhava
# Freebase ID: /m/0cm7w1, Wikidata ID: Q6529576, Label: Bihari people
# Freebase ID: /m/0cnvdq1, Wikidata ID: Q7429945, Label: Scandinavian Americans
# Freebase ID: /m/041rx, Wikidata ID: Q7325, Label: Jewish people
# Freebase ID: /m/07hwkr, Wikidata ID: Q49078, Label: White Americans
# Freebase ID: /m/065b6q, Wikidata ID: Q115026, Label: Swedish Americans
# Freebase ID: /m/06gbnc, Wikidata ID: Q188353, Label: Welsh people
# Freebase ID: /m/042gtr, Wikidata ID: Q1041917, Label: Spanish Americans
# Freebase ID: /m/0g0x7_, Wikidata ID: Q1282294, Label: Gujarati people
# Freebase ID: /m/03295l, Wikidata ID: Q1413685, Label: Filipino Americans
# Freebase ID: /m/0g8_vp, Wikidata ID: Q5029681, Label: Canadian Americans
# Freebase ID: /m/0x67, Wikidata ID: Q49085, Label: African Americans
# Freebase ID: /m/03bkbh, Wikidata ID: Q170826, Label: Irish people
# Freebase ID: /m/01hwt, Wikidata ID: Q817393, Label: Black people
# Freebase ID: /m/0dryh9k, Wikidata ID: Q862086, Label: Indians
# Freebase ID: /m/0xnvg, Wikidata ID: Q974693, Label: Italian Americans
# Freebase ID: /m/07bch9, Wikidata ID: Q3476361, Label: Scottish Americans
# Freebase ID: /m/022fdt, Wikidata ID: Q79797, Label: Armenians
# Freebase ID: /m/04mvp8, Wikidata ID: Q1267987, Label: Malayali
# Freebase ID: /m/09m6hr, Wikidata ID: Q418708, Label: Telugu people
# Freebase ID: /m/0268d21, Wikidata ID: Q1261777, Label: Serbian Americans
# Freebase ID: /m/03w9bjf, Wikidata ID: Q4115170, Label: British Indian
# Freebase ID: /m/0fqp6zk, Wikidata ID: Q4887679, Label: Bengali Hindus
# Freebase ID: /m/0g96wd, Wikidata ID: Q7994501, Label: White British
# Freebase ID: /m/02sch9, Wikidata ID: Q854323, Label: Punjabis
# Freebase ID: /m/0d7wh, Wikidata ID: Q842438, Label: British
# Freebase ID: /m/0dllcfn, Wikidata ID: Q4689218, Label: Afghans in India
# Freebase ID: /m/063k3h, Wikidata ID: Q7435494, Label: Scotch-Irish Americans
# Freebase ID: /m/0fpjs3j, Wikidata ID: Q7901501, Label: Uruguayans
# Freebase ID: /m/01rv7x, Wikidata ID: Q173491, Label: Tamil
# Freebase ID: /m/01g7zj, Wikidata ID: Q581921, Label: Mexican Americans
# Freebase ID: /m/01336l, Wikidata ID: Q727928, Label: Asian Americans
# Freebase ID: /m/0cn68, Wikidata ID: Q1156766, Label: Japanese Americans
# Freebase ID: /m/029f2r, Wikidata ID: Q1258074, Label: Sindhis
# Freebase ID: /m/09743, Wikidata ID: Q2556103, Label: Pashtuns
# Freebase ID: /m/0d9q7j, Wikidata ID: Q3531196, Label: Gaud Saraswat Brahmin
# Freebase ID: /m/02p_gby, Wikidata ID: Q16197531, Label: Rusyn American
# Freebase ID: /m/04q7gbh, Wikidata ID: Q846570, Label: Americans
# Freebase ID: /m/022dp5, Wikidata ID: Q1189552, Label: Polish Americans
# Freebase ID: /m/071x0k, Wikidata ID: Q4172847, Label: Filipino people
# Freebase ID: /m/0bh91q8, Wikidata ID: Q5622783, Label: Guyanese Americans
# Freebase ID: /m/02g7sp, Wikidata ID: Q6071674, Label: Irish migration to Great Britain
# Freebase ID: /m/02y_9mh, Wikidata ID: Q6365797, Label: Kanyakubja Brahmins
# Freebase ID: /m/013xrm, Wikidata ID: Q42884, Label: Germans
# Freebase ID: /m/04nrnz, Wikidata ID: Q1672477, Label: Iranian peoples
# Freebase ID: /m/075_n6, Wikidata ID: Q3521909, Label: Bunt (RAJPUT)
# Freebase ID: /m/0912ll, Wikidata ID: Q5290725, Label: Dominican Americans
# Freebase ID: /m/0cmdl5l, Wikidata ID: Q7681244, Label: Tamil Brahmin
# Freebase ID: /m/04y29, Wikidata ID: Q47740, Label: Muslim
# Freebase ID: /m/06mvq, Wikidata ID: Q165192, Label: Swedes
# Freebase ID: /m/08hpk0, Wikidata ID: Q948126, Label: Hungarian Americans
# Freebase ID: /m/09k5jvk, Wikidata ID: Q1209676, Label: Mexicans
# Freebase ID: /m/05sf2x, Wikidata ID: Q2254415, Label: Italian Canadians
# Freebase ID: /m/0583cz, Wikidata ID: Q3243684, Label: Kayastha
# Freebase ID: /m/047948f, Wikidata ID: Q3476364, Label: Scottish Australians
# Freebase ID: /m/0gkxl2, Wikidata ID: Q7258666, Label: Stateside Puerto Ricans
# Freebase ID: /m/0dbxy, Wikidata ID: Q105405, Label: Cherokee
# Freebase ID: /m/019lrz, Wikidata ID: Q237534, Label: Austrians
# Freebase ID: /m/0bpjh3, Wikidata ID: Q402913, Label: Bengali
# Freebase ID: /m/012c1l, Wikidata ID: Q857880, Label: French Canadians
# Freebase ID: /m/04ggbzy, Wikidata ID: Q2704511, Label: White Africans of European ancestry
# Freebase ID: /m/025rpb0, Wikidata ID: Q58669, Label: Hispanic and Latino Americans
# Freebase ID: /m/03ttfc, Wikidata ID: Q160894, Label: Spaniards
# Freebase ID: /m/07mqps, Wikidata ID: Q1058496, Label: Dutch Americans
# Freebase ID: /m/03bx0k4, Wikidata ID: Q1142927, Label: Hongkongers
# Freebase ID: /m/025_0f0, Wikidata ID: Q124216, Label: Swiss
# Freebase ID: /m/0j6x8, Wikidata ID: Q12060728, Label: Aboriginal Australians
# Freebase ID: /m/02czfr, Wikidata ID: Q365539, Label: Black Canadians
# Freebase ID: /m/0bbz66j, Wikidata ID: Q1318423, Label: Australians
# Freebase ID: /m/0f0gt_, Wikidata ID: Q4058325, Label: Asian people
# Freebase ID: /m/0d8qh0, Wikidata ID: Q4256383, Label: Indonesian Americans
# Freebase ID: /m/03gskx0, Wikidata ID: Q4823807, Label: Australian Americans
# Freebase ID: /m/027n1m6, Wikidata ID: Q7541523, Label: Slovak Americans
# Freebase ID: /m/0bnzjx, Wikidata ID: Q16242047, Label: Criollo people
# Freebase ID: /m/0470lk, Wikidata ID: Q165235, Label: Bosnians
# Freebase ID: /m/01swvz, Wikidata ID: Q388101, Label: Anglo-Celtic Australians
# Freebase ID: /m/032j30, Wikidata ID: Q1283606, Label: Native Hawaiians
# Freebase ID: /m/0222hg, Wikidata ID: Q1645980, Label: Jaat
# Freebase ID: /m/09cqth, Wikidata ID: Q1780828, Label: Romanichal
# Freebase ID: /m/03vv99, Wikidata ID: Q4969441, Label: British Americans
# Freebase ID: /m/04dzwby, Wikidata ID: Q5501711, Label: French Chilean
# Freebase ID: /m/0268_k, Wikidata ID: Q164714, Label: Danes
# Freebase ID: /m/03lmx1, Wikidata ID: Q181634, Label: Scottish people
# Freebase ID: /m/038723, Wikidata ID: Q1150312, Label: Greek Americans
# Freebase ID: /m/023mqw, Wikidata ID: Q1996554, Label: Kashmiri Pandit
# Freebase ID: /m/0828vj, Wikidata ID: Q7697877, Label: Telugu Brahmins
# Freebase ID: /m/0ffj5g, Wikidata ID: Q324216, Label: Austrian Americans
# Freebase ID: /m/0h2138, Wikidata ID: Q518188, Label: Czech Americans
# Freebase ID: /m/0bkbz, Wikidata ID: Q853581, Label: names of the Greeks
# Freebase ID: /m/04znbg, Wikidata ID: Q16149615, Label: African-American Jews
# Freebase ID: /m/01kg2v, Wikidata ID: Q47140, Label: Brahmin
# Freebase ID: /m/01n94b, Wikidata ID: Q171336, Label: Slovaks
# Freebase ID: /m/06v41q, Wikidata ID: Q1369944, Label: French Americans
# Freebase ID: /m/0bhsnb, Wikidata ID: Q1815623, Label: Sri Lankan Tamils
# Freebase ID: /m/08v2k7, Wikidata ID: Q2257191, Label: Italian Australians
# Freebase ID: /m/03cbkrf, Wikidata ID: Q4065203, Label: English Australian
# Freebase ID: /m/0g48m4, Wikidata ID: Q6510842, Label: Lebanese Americans
# Freebase ID: /m/0462jl6, Wikidata ID: Q7144694, Label: Pathani
# Freebase ID: /m/09vmyh, Wikidata ID: Q1280677, Label: Serbs of Croatia
# Freebase ID: /m/0fj1k9, Wikidata ID: Q7507476, Label: Sicilian Americans
# Freebase ID: /m/0g5y6, Wikidata ID: Q133032, Label: Hungarians
# Freebase ID: /m/0bymc, Wikidata ID: Q200263, Label: Parsi
# Freebase ID: /m/0d2by, Wikidata ID: Q1146100, Label: Chinese Americans
# Freebase ID: /m/0ffhz3, Wikidata ID: Q1849258, Label: Albanian Americans
# Freebase ID: /m/0c2hxm, Wikidata ID: Q5147921, Label: Colombian Americans
# Freebase ID: /m/03cjjy0, Wikidata ID: Q5602103, Label: Greeks in South Africa
# Freebase ID: /m/0fng3k, Wikidata ID: Q6164703, Label: Jatt Sikh
# Freebase ID: /m/06j2v, Wikidata ID: Q8060, Label: Romani people
# Freebase ID: /m/01ylpf, Wikidata ID: Q49540, Label: Latvians
# Freebase ID: /m/09zyn5, Wikidata ID: Q188779, Label: Norwegians
# Freebase ID: /m/04y8_bm, Wikidata ID: Q6935055, Label: multiracial American
# Freebase ID: /m/06fczy, Wikidata ID: Q40809606, Label: Black Irish
# Freebase ID: /m/0790v, Wikidata ID: Q40477, Label: Slavs
# Freebase ID: /m/05l3g_, Wikidata ID: Q200569, Label: Dutch
# Freebase ID: /m/05g0f1, Wikidata ID: Q415693, Label: Akan people
# Freebase ID: /m/08gzsf, Wikidata ID: Q1249914, Label: Konkani people
# Freebase ID: /m/04czx7, Wikidata ID: Q1974839, Label: Chinese Filipino
# Freebase ID: /m/0bs7l_v, Wikidata ID: Q3310017, Label: Pakistanis
# Freebase ID: /m/04jq32s, Wikidata ID: Q3635166, Label: Nepali Indian
# Freebase ID: /m/071drf, Wikidata ID: Q7404928, Label: Chaliyan
# Freebase ID: /m/0dv5vw, Wikidata ID: Q3349057, Label: Pacific Islander Americans
# Freebase ID: /m/03f3sf, Wikidata ID: Q3916714, Label: Romanian Americans
# Freebase ID: /m/04608z, Wikidata ID: Q4690200, Label: Afro Trinidadians and Tobagonians
# Freebase ID: /m/07j80c, Wikidata ID: Q7409937, Label: Samoan Americans
# Freebase ID: /m/062_25, Wikidata ID: Q1065371, Label: Italian Brazilians
# Freebase ID: /m/033qxt, Wikidata ID: Q501837, Label: Mizrahi Jews
# Freebase ID: /m/04f581, Wikidata ID: Q1193808, Label: Norwegian Americans
# Freebase ID: /m/047bp1r, Wikidata ID: Q5147919, Label: Colombian Australian
# Freebase ID: /m/05748, Wikidata ID: Q6122670, Label: Māori
# Freebase ID: /m/08xbxs, Wikidata ID: Q7125804, Label: Pakistani Canadians
# Freebase ID: /m/02q206y, Wikidata ID: Q10859769, Label: Iranians in the United Kingdom
# Freebase ID: /m/01trsl, Wikidata ID: Q392316, Label: First Nations
# Freebase ID: /m/04_hr_, Wikidata ID: Q1003039, Label: Chinese Singaporeans
# Freebase ID: /m/033njm, Wikidata ID: Q3154490, Label: Irish Canadians
# Freebase ID: /m/02p4q5p, Wikidata ID: Q3267812, Label: Portuguese Americans
# Freebase ID: /m/097nms, Wikidata ID: Q3244280, Label: Black Britons
# Freebase ID: /m/017sq0, Wikidata ID: Q7434888, Label: Eurasian
# Freebase ID: /m/026c9dq, Wikidata ID: Q7416717, Label: Chilean Americans
# Freebase ID: /m/01nbcy, Wikidata ID: Q44614, Label: Taiwanese Americans
# Freebase ID: /m/03yk6g, Wikidata ID: Q388467, Label: Afro-Cuban
# Freebase ID: /m/0ckk60, Wikidata ID: Q785378, Label: White South Africans
# Freebase ID: /m/018s6c, Wikidata ID: Q875556, Label: Israelis
# Freebase ID: /m/0btrm4, Wikidata ID: Q2325516, Label: Armenian Americans
# Freebase ID: /m/02cm28, Wikidata ID: Q2935829, Label: English Canadians
# Freebase ID: /m/0bfjm7, Wikidata ID: Q3094841, Label: Welsh Americans
# Freebase ID: /m/067lwk, Wikidata ID: Q5187097, Label: Croatian Canadians
# Freebase ID: /m/02wcbj_, Wikidata ID: Q11685635, Label: Bolivian Americans
# Freebase ID: /m/0432mrk, Wikidata ID: Q36747, Label: Indigenous peoples of the Americas
# Freebase ID: /m/059_w, Wikidata ID: Q49297, Label: Native Americans in the United States
# Freebase ID: /m/0289z8v, Wikidata ID: Q2533689, Label: Dalmatian Italians
# Freebase ID: /m/02jvpv, Wikidata ID: Q2552898, Label: Kiwi
# Freebase ID: /m/065z7w_, Wikidata ID: Q6913088, Label: Moroccan Americans
# Freebase ID: /m/013b6_, Wikidata ID: Q34069, Label: Ashkenazi Jews
# Freebase ID: /m/0fqz6, Wikidata ID: Q686949, Label: Cajun
# Freebase ID: /m/02qv_h_, Wikidata ID: Q3303849, Label: Syrian Americans
# Freebase ID: /m/02rbdlq, Wikidata ID: Q7437641, Label: Scottish Canadians
# Freebase ID: /m/0b__fv3, Wikidata ID: Q7681242, Label: Tamil Americans
# Freebase ID: /m/01xttr, Wikidata ID: Q118281, Label: Kannada people
# Freebase ID: /m/02p444n, Wikidata ID: Q1195125, Label: Cubans
# Freebase ID: /m/0ch3pqf, Wikidata ID: Q1377716, Label: Belgians
# Freebase ID: /m/03cdk7b, Wikidata ID: Q2580491, Label: مسح
# Freebase ID: /m/02r_qms, Wikidata ID: Q873625, Label: Brazilians
# Freebase ID: /m/095mw2, Wikidata ID: Q1633149, Label: Soviet people
# Freebase ID: /m/01g0y_, Wikidata ID: Q255872, Label: Ojibwe
# Freebase ID: /m/0fk1z, Wikidata ID: Q1211934, Label: Hispanic
# Freebase ID: /m/052r3t, Wikidata ID: Q2975309, Label: Bhutia
# Freebase ID: /m/0ffjqy, Wikidata ID: Q3003133, Label: Croatian Americans
# Freebase ID: /m/0g4pffv, Wikidata ID: Q4400590, Label: Russian Canadians
# Freebase ID: /m/04ydrsn, Wikidata ID: Q12404065, Label: Israeli Americans
# Freebase ID: /m/013s3n, Wikidata ID: Q170217, Label: Czechs
# Freebase ID: /m/09gp4, Wikidata ID: Q483569, Label: Belarusians
# Freebase ID: /m/04mmhj, Wikidata ID: Q2658204, Label: British Chinese
# Freebase ID: /m/02pzb09, Wikidata ID: Q3573855, Label: Castilians
# Freebase ID: /m/067lrj, Wikidata ID: Q5601752, Label: Greek Canadians
# Freebase ID: /m/01j2qv, Wikidata ID: Q276879, Label: Korean Americans
# Freebase ID: /m/09gk_6h, Wikidata ID: Q2365041, Label: Argentines
# Freebase ID: /m/0466nw8, Wikidata ID: Q2606511, Label: Lebanese people
# Freebase ID: /m/08cjt2, Wikidata ID: Q6363876, Label: Karnataka Brahmins
# Freebase ID: /m/0bfrrj, Wikidata ID: Q6894521, Label: Mohyal
# Freebase ID: /m/0cx3p, Wikidata ID: Q45315, Label: Berber
# Freebase ID: /m/07d_p8, Wikidata ID: Q244504, Label: Catalans
# Freebase ID: /m/0dj8k3, Wikidata ID: Q702718, Label: British Jews
# Freebase ID: /m/013s2p, Wikidata ID: Q940348, Label: Bosniaks
# Freebase ID: /m/09chmw, Wikidata ID: Q3803351, Label: Filipino people of Spanish ancestry
# Freebase ID: /m/078vc, Wikidata ID: Q582779, Label: Sikh
# Freebase ID: /m/026cybk, Wikidata ID: Q3026394, Label: Serbian Canadians
# Freebase ID: /m/09y7x4, Wikidata ID: Q3707477, Label: Filipino Australians
# Freebase ID: /m/06lshc, Wikidata ID: Q7042073, Label: Niyogi
# Freebase ID: /m/0268pvf, Wikidata ID: Q9149944, Label: Iraqi Americans
# Freebase ID: /m/013b7g, Wikidata ID: Q102251, Label: Sephardi Jews
# Freebase ID: /m/074w_m, Wikidata ID: Q140713, Label: Tulu people
# Freebase ID: /m/067lts, Wikidata ID: Q3395438, Label: Polish Canadians
# Freebase ID: /m/03cl2pz, Wikidata ID: Q4416722, Label: Serbs in the United Kingdom
# Freebase ID: /m/02p7gyv, Wikidata ID: Q4958704, Label: Brazilian Americans
# Freebase ID: /m/03sx6v, Wikidata ID: Q5030929, Label: German Canadians
# Freebase ID: /m/0404kdr, Wikidata ID: Q7409949, Label: Samoan New Zealanders
# Freebase ID: /m/0ft9bs, Wikidata ID: Q7586050, Label: Sri Lankan Tamil diaspora
# Freebase ID: /m/04k02l, Wikidata ID: Q18356677, Label: Marwari people
# Freebase ID: /m/06rd7, Wikidata ID: Q48199, Label: Sámi people
# Freebase ID: /m/034s7b, Wikidata ID: Q368125, Label: Anglo-Indian people
# Freebase ID: /m/016f5d, Wikidata ID: Q388264, Label: Blackfoot Confederacy
# Freebase ID: /m/07gzw5, Wikidata ID: Q2526737, Label: Kapampangan people
# Freebase ID: /m/086wp0, Wikidata ID: Q2527423, Label: Ilocano
# Freebase ID: /m/0640_7q, Wikidata ID: Q16152214, Label: Moroccan Jews
# Freebase ID: /m/0761bp, Wikidata ID: Q5102351, Label: Chitrapur Saraswat Brahmin
# Freebase ID: /m/03ndvw, Wikidata ID: Q216151, Label: Vietnamese people
# Freebase ID: /m/027vy0s, Wikidata ID: Q2033181, Label: White Latin American
# Freebase ID: /m/0266mf0, Wikidata ID: Q4115525, Label: Palestinians in the United States
# Freebase ID: /m/02vkw95, Wikidata ID: Q5334370, Label: Ecuadorian Americans
# Freebase ID: /m/01c034, Wikidata ID: Q383946, Label: Lao people
# Freebase ID: /m/0br_8h, Wikidata ID: Q752526, Label: Galicians
# Freebase ID: /m/025x6k1, Wikidata ID: Q1262389, Label: Serbs in North Macedonia
# Freebase ID: /m/0gf5k1, Wikidata ID: Q3804346, Label: Italians in the United Kingdom
# Freebase ID: /m/051wcch, Wikidata ID: Q4996189, Label: Bulgarian Canadians
# Freebase ID: /m/0288fw3, Wikidata ID: Q7210044, Label: Poles in the United Kingdom
# Freebase ID: /m/0j4w_, Wikidata ID: Q167420, Label: Croats
# Freebase ID: /m/04hlx1, Wikidata ID: Q245794, Label: Greek Cypriots
# Freebase ID: /m/01d7kx, Wikidata ID: Q726673, Label: Swedish-speaking population of Finland
# Freebase ID: /m/0665pp, Wikidata ID: Q719549, Label: Rohilla
# Freebase ID: /m/051x6yk, Wikidata ID: Q1087095, Label: Arabs in Bulgaria
# Freebase ID: /m/0c3wsgg, Wikidata ID: Q1891793, Label: Moroccans
# Freebase ID: /m/07g8yp, Wikidata ID: Q4999416, Label: Burmese Americans
# Freebase ID: /m/04lhn7b, Wikidata ID: Q7565427, Label: South African Americans
# Freebase ID: /m/0180zw, Wikidata ID: Q25467191, Label: Q25467191
# Freebase ID: /m/01p7s6, Wikidata ID: Q1026, Label: Poles
# Freebase ID: /m/0fk3s, Wikidata ID: Q107434, Label: Sioux
# Freebase ID: /m/0318mh, Wikidata ID: Q170284, Label: Finns
# Freebase ID: /m/01vsch, Wikidata ID: Q201111, Label: Aromanians
# Freebase ID: /m/025tvhm, Wikidata ID: Q1061510, Label: Egyptians
# Freebase ID: /m/0b79c7, Wikidata ID: Q1196649, Label: Kashmiri people
# Freebase ID: /m/05sycg, Wikidata ID: Q2722871, Label: British Asians
# Freebase ID: /m/0152s7, Wikidata ID: Q2849692, Label: Anglo-Irish people
# Freebase ID: /m/0738n4, Wikidata ID: Q4713742, Label: Hmong Americans
# Freebase ID: /m/09fqz7, Wikidata ID: Q5187093, Label: Croatian Australians
# Freebase ID: /m/0520604, Wikidata ID: Q12352241, Label: Mangaloreans
# Freebase ID: /m/0338zd, Wikidata ID: Q1200528, Label: Malaysian Chinese
# Freebase ID: /m/04_tz7, Wikidata ID: Q7541693, Label: Slovene Americans
# Freebase ID: /m/03cnzsg, Wikidata ID: Q7981927, Label: Welsh Italians
# Freebase ID: /m/03r_k, Wikidata ID: Q189975, Label: Inuit
# Freebase ID: /m/0hj35, Wikidata ID: Q207996, Label: Xhosa people
# Freebase ID: /m/04zjjt, Wikidata ID: Q573598, Label: history of the Jews in India
# Freebase ID: /m/0fp54b, Wikidata ID: Q711083, Label: Koryo-saram
# Freebase ID: /m/0150zs, Wikidata ID: Q787519, Label: Arab Americans
# Freebase ID: /m/0ffjvd, Wikidata ID: Q2505231, Label: Ukrainian Americans
# Freebase ID: /m/02rp50t, Wikidata ID: Q2696805, Label: Dutch Australian
# Freebase ID: /m/07hyjp, Wikidata ID: Q3154488, Label: Irish Australians
# Freebase ID: /m/027lf0d, Wikidata ID: Q5766070, Label: Hindkowans
# Freebase ID: /m/01sq7s, Wikidata ID: Q116971, Label: Mohawk
# Freebase ID: /m/046j25, Wikidata ID: Q1886046, Label: Lumbee
# Freebase ID: /m/03d26m9, Wikidata ID: Q2035264, Label: Hondurans
# Freebase ID: /m/03d19xz, Wikidata ID: Q5030922, Label: Canadians in the United Kingdom
# Freebase ID: /m/03kbr, Wikidata ID: Q10090, Label: Hindu
# Freebase ID: /m/031_sd, Wikidata ID: Q337487, Label: Rajput
# Freebase ID: /m/05mtdy, Wikidata ID: Q3150506, Label: Indo-Canadians
# Freebase ID: /m/05vhv7, Wikidata ID: Q3521791, Label: Mudaliar
# Freebase ID: /m/0fxmtg, Wikidata ID: Q5892930, Label: Honduran Americans
# Freebase ID: /m/03x_fq7, Wikidata ID: Q12060728, Label: Aboriginal Australians
# Freebase ID: /m/012f86, Wikidata ID: Q44806, Label: Ukrainians
# Freebase ID: /m/02gx2x, Wikidata ID: Q49209, Label: Javanese
# Freebase ID: /m/01nft3, Wikidata ID: Q377085, Label: Assyrian people
# Freebase ID: /m/0bvnws, Wikidata ID: Q648255, Label: Kabyle people
# Freebase ID: /m/0d32d1, Wikidata ID: Q2195308, Label: Chinese Jamaicans
# Freebase ID: /m/04l_pt, Wikidata ID: Q2408653, Label: Thai Chinese
# Freebase ID: /m/01tyl3, Wikidata ID: Q2657969, Label: Vietnamese Americans
# Freebase ID: /m/08yg47, Wikidata ID: Q3352263, Label: Bengali Brahmins
# Freebase ID: /m/03x_lpj, Wikidata ID: Q4445351, Label: Sudanese Arabs
# Freebase ID: /m/0647lm, Wikidata ID: Q7125803, Label: Pakistani Americans
# Freebase ID: /m/09snp5, Wikidata ID: Q19891823, Label: Muhajir diaspora
# Freebase ID: /m/064pj, Wikidata ID: Q484206, Label: Persians
# Freebase ID: /m/01mw1s, Wikidata ID: Q1207351, Label: Chinese Canadians
# Freebase ID: /m/05qb937, Wikidata ID: Q2996826, Label: Venezuelans
# Freebase ID: /m/07n8wy, Wikidata ID: Q3595742, Label: Agrawal
# Freebase ID: /m/02r3wfk, Wikidata ID: Q4970177, Label: British Jamaicans
# Freebase ID: /m/0c41n, Wikidata ID: Q415054, Label: Acadians
# Freebase ID: /m/05c60ml, Wikidata ID: Q1276073, Label: Chileans
# Freebase ID: /m/07lv5x, Wikidata ID: Q4842385, Label: Bahamian Americans
# Freebase ID: /m/01267, Wikidata ID: Q179248, Label: Albanians
# Freebase ID: /m/03vghh, Wikidata ID: Q178630, Label: Portuguese
# Freebase ID: /m/0152wh, Wikidata ID: Q1945786, Label: Chinese Indonesians
# Freebase ID: /m/02vkd28, Wikidata ID: Q5639720, Label: Haitian Americans
# Freebase ID: /m/04csgrq, Wikidata ID: Q7511479, Label: Sierra Leoneans in the United Kingdom
# Freebase ID: /m/03h1dq9, Wikidata ID: Q3026377, Label: Indian diaspora in France
# Freebase ID: /m/06k6sl, Wikidata ID: Q5099734, Label: Swedish Canadians
# Freebase ID: /m/02qv716, Wikidata ID: Q5501667, Label: French-speaking Quebecer
# Freebase ID: /m/0dq1q, Wikidata ID: Q117191, Label: Cree
# Freebase ID: /m/026zlyd, Wikidata ID: Q1075929, Label: African people
# Freebase ID: /m/0b8yvr, Wikidata ID: Q7633360, Label: Sudanese Australians
# Freebase ID: /m/09tqq8q, Wikidata ID: Q15307583, Label: Ghanaian
# Freebase ID: /m/078ds, Wikidata ID: Q932244, Label: Sinhalese
# Freebase ID: /m/026kx7g, Wikidata ID: Q2997267, Label: Colombians
# Freebase ID: /m/0268xtg, Wikidata ID: Q3026395, Label: Serbian Australians
# Freebase ID: /m/04wy6k, Wikidata ID: Q5025138, Label: Cambodian Americans
# Freebase ID: /m/03wbmrc, Wikidata ID: Q5555460, Label: Ghanaian Americans
# Freebase ID: /m/02rm7_9, Wikidata ID: Q7171212, Label: Peruvians in the United Kingdom
# Freebase ID: /m/0dqrh8, Wikidata ID: Q7209875, Label: Polish Australians
# Freebase ID: /m/03fk0c, Wikidata ID: Q191356, Label: Icelanders
# Freebase ID: /m/03q819, Wikidata ID: Q236807, Label: Yugoslavs
# Freebase ID: /m/03hf_6z, Wikidata ID: Q285828, Label: Gibraltarian people
# Freebase ID: /m/021pd, Wikidata ID: Q324516, Label: Choctaw
# Freebase ID: /m/0165md, Wikidata ID: Q1208167, Label: Ryukyuan people
# Freebase ID: /m/0ftlzz, Wikidata ID: Q4272184, Label: Luxembourgish Americans
# Freebase ID: /m/02r11hz, Wikidata ID: Q15055500, Label: Lebanese Mexicans
# Freebase ID: /m/03x1x, Wikidata ID: Q1421590, Label: Five Nations
# Freebase ID: /m/01ywdy, Wikidata ID: Q173302, Label: Estonians
# Freebase ID: /m/01gr8h, Wikidata ID: Q200513, Label: Sherpa
# Freebase ID: /m/039z49, Wikidata ID: Q212106, Label: Dinka people
# Freebase ID: /m/03ty8_, Wikidata ID: Q1421205, Label: Lithuanian Jews
# Freebase ID: /m/0ffhvl, Wikidata ID: Q2464565, Label: Turkish Americans
# Freebase ID: /m/067lv3, Wikidata ID: Q2589229, Label: Dutch Canadians
# Freebase ID: /m/0bms44, Wikidata ID: Q4386404, Label: Louisiana Creole people
# Freebase ID: /m/04lgl9t, Wikidata ID: Q4825530, Label: Austrians in the United Kingdom
# Freebase ID: /m/01hm_, Wikidata ID: Q968848, Label: Bohemian People
# Freebase ID: /m/03fvrb, Wikidata ID: Q3239254, Label: Khatri
# Freebase ID: /m/0g5rkt4, Wikidata ID: Q509590, Label: Corsicans
# Freebase ID: /m/03zcwh, Wikidata ID: Q1976298, Label: Ukrainian Canadians
# Freebase ID: /m/04lfc70, Wikidata ID: Q4793325, Label: Armenians in Italy
# Freebase ID: /m/09cd0m, Wikidata ID: Q5448617, Label: Filipino mestizo
# Freebase ID: /m/07s9g04, Wikidata ID: Q6496280, Label: Latin American British
# Freebase ID: /m/0d8qls, Wikidata ID: Q7586018, Label: Sri Lankan Americans
# Freebase ID: /m/013s41, Wikidata ID: Q133255, Label: Bulgarians
# Freebase ID: /m/01l0ty, Wikidata ID: Q187985, Label: Tibetan people
# Freebase ID: /m/01vr3v, Wikidata ID: Q485150, Label: Romanians
# Freebase ID: /m/06y24j, Wikidata ID: Q1113048, Label: Iranian Americans
# Freebase ID: /m/02rdfpy, Wikidata ID: Q7406487, Label: Salvadoran Americans
# Freebase ID: /m/09g34_, Wikidata ID: Q310983, Label: Malagasy people
# Freebase ID: /m/02dd5z, Wikidata ID: Q340520, Label: Aceh
# Freebase ID: /m/05ms3p0, Wikidata ID: Q620089, Label: Punjabi diaspora
# Freebase ID: /m/04pnf, Wikidata ID: Q1464994, Label: Latino
# Freebase ID: /m/07s49c2, Wikidata ID: Q5098860, Label: Chileans in the United Kingdom
# Freebase ID: /m/0bvjpj, Wikidata ID: Q7032863, Label: Nigerian Americans
# Freebase ID: /m/05cc9h, Wikidata ID: Q241696, Label: Somalis
# Freebase ID: /m/03m9my8, Wikidata ID: Q2686890, Label: Arab Mexican
# Freebase ID: /m/03h11s3, Wikidata ID: Q4200801, Label: Indian Australian
# Freebase ID: /m/0gtwjz6, Wikidata ID: Q5029742, Label: Canadian Australian
# Freebase ID: /m/03cmqbt, Wikidata ID: Q7573435, Label: Spanish people of Filipino ancestry
# Freebase ID: /m/01_5cg, Wikidata ID: Q102090, Label: Apache
# Freebase ID: /m/01crfj, Wikidata ID: Q146744, Label: Copts
# Freebase ID: /m/02m0kh, Wikidata ID: Q819186, Label: Mandinka people
# Freebase ID: /m/0ftwg, Wikidata ID: Q207050, Label: Buryats
# Freebase ID: /m/01kb9y, Wikidata ID: Q1378555, Label: multiracial people
# Freebase ID: /m/03lnnd, Wikidata ID: Q4450068, Label: Thai Americans
# Freebase ID: /m/04lhnps, Wikidata ID: Q4858560, Label: Barbadian Americans
# Freebase ID: /m/0b3zsn, Wikidata ID: Q5602121, Label: Greeks in the United Kingdom
# Freebase ID: /m/04hqxn, Wikidata ID: Q170352, Label: Transylvanian Saxons
# Freebase ID: /m/01f9bg, Wikidata ID: Q1417088, Label: Iñupiaq people
# Freebase ID: /m/0ffk5n, Wikidata ID: Q4356656, Label: Latvian Americans
# Freebase ID: /m/03gy1h2, Wikidata ID: Q7129967, Label: Panamanian Americans
# Freebase ID: /m/02vys3l, Wikidata ID: Q7919819, Label: Venezuelan Americans
# Freebase ID: /m/0fp4n, Wikidata ID: Q35565, Label: Tatars
# Freebase ID: /m/033fjj, Wikidata ID: Q1537653, Label: Ho-Chunk
# Freebase ID: /m/0c_lbq, Wikidata ID: Q2598589, Label: Armenians of Russia
# Freebase ID: /m/05sng, Wikidata ID: Q4115874, Label: culture of Palestine
# Freebase ID: /m/06bkf, Wikidata ID: Q7273097, Label: Québécois
# Freebase ID: /m/01gby2, Wikidata ID: Q36692, Label: Zhuang people
# Freebase ID: /m/0301xt, Wikidata ID: Q4770873, Label: Dene
# Freebase ID: /m/0960kn, Wikidata ID: Q5030924, Label: Danish Canadians
# Freebase ID: /m/0c50f, Wikidata ID: Q262457, Label: Métis
# Freebase ID: /m/04118b, Wikidata ID: Q321090, Label: German Brazilians
# Freebase ID: /m/0fk55, Wikidata ID: Q322951, Label: Cheyennes
# Freebase ID: /m/01hphz, Wikidata ID: Q925034, Label: Indian diaspora
# Freebase ID: /m/042199j, Wikidata ID: Q928333, Label: Spaniards in Mexico
# Freebase ID: /m/032m0b, Wikidata ID: Q5094202, Label: Chettiar
# Freebase ID: /m/0166vx, Wikidata ID: Q45321045, Label: Tejano
# Freebase ID: /m/0xff, Wikidata ID: Q35323, Label: Arabs
# Freebase ID: /m/097r55, Wikidata ID: Q125564, Label: Manx people
# Freebase ID: /m/013z8m, Wikidata ID: Q145665, Label: Manchu
# Freebase ID: /m/08c25t, Wikidata ID: Q217397, Label: Wolof people
# Freebase ID: /m/06dy2k, Wikidata ID: Q1064662, Label: Serbs of Bosnia and Herzegovina
# Freebase ID: /m/05y2yj, Wikidata ID: Q3453511, Label: Baltic Russians
# Freebase ID: /m/04wysy, Wikidata ID: Q219517, Label: Dalit
# Freebase ID: /m/0dtkkb, Wikidata ID: Q2986879, Label: British African-Caribbean people
# Freebase ID: /m/068y7m, Wikidata ID: Q4269361, Label: Greek Australians
# Freebase ID: /m/05bzpzx, Wikidata ID: Q5201739, Label: Czech Australians
# Freebase ID: /m/044bp_, Wikidata ID: Q6025447, Label: Indo Caribbeans
# Freebase ID: /m/01srl7, Wikidata ID: Q106974, Label: Ossetians
# Freebase ID: /m/035b50, Wikidata ID: Q1144461, Label: Japanese Brazilians
# Freebase ID: /m/0br_9j, Wikidata ID: Q1365830, Label: Romani people in Spain
# Freebase ID: /m/0dn1_0, Wikidata ID: Q1675074, Label: Italian immigration to Mexico
# Freebase ID: /m/064rb5l, Wikidata ID: Q1752440, Label: Israeli Jews
# Freebase ID: /m/04fh1b, Wikidata ID: Q2712961, Label: Afro-Asians
# Freebase ID: /m/047q05d, Wikidata ID: Q6511009, Label: Lebanese people in the United Kingdom
# Freebase ID: /m/01g3rx, Wikidata ID: Q109402, Label: Aymara
# Freebase ID: /m/027936c, Wikidata ID: Q3059102, Label: Gin people
# Freebase ID: /m/01km_m, Wikidata ID: Q15863, Label: Slovenes
# Freebase ID: /m/03b_13l, Wikidata ID: Q4302645, Label: Swedish Australian
# Freebase ID: /m/06vb7b, Wikidata ID: Q10859771, Label: Iranian Canadians
# Freebase ID: /m/026d074, Wikidata ID: Q16839420, Label: Goans
# Freebase ID: /m/06w4lv, Wikidata ID: Q17054305, Label: Indo-Guyanese
# Freebase ID: /m/03hjx6f, Wikidata ID: Q4920978, Label: Black Hispanic and Latino Americans
# Freebase ID: /m/029q52, Wikidata ID: Q18973, Label: Georgians
# Freebase ID: /m/01h4n, Wikidata ID: Q126756, Label: Basque people
# Freebase ID: /m/07wsyr, Wikidata ID: Q472834, Label: Thai people
# Freebase ID: /m/03nz70, Wikidata ID: Q828398, Label: Hutsuls
# Freebase ID: /m/09c8kp, Wikidata ID: Q4690182, Label: Afro-Guyanese
# Freebase ID: /m/02wz7j, Wikidata ID: Q1572875, Label: Oneida
# Freebase ID: /m/09r2kh, Wikidata ID: Q46295, Label: peoples of the Caucasus
# Freebase ID: /m/012fh, Wikidata ID: Q385799, Label: Afrikaners
# Freebase ID: /m/033qt1, Wikidata ID: Q482942, Label: Azerbaijanis
# Freebase ID: /m/02ry8mk, Wikidata ID: Q2983498, Label: Sierra Leone Creole people
# Freebase ID: /m/08j1fb, Wikidata ID: Q4855425, Label: Bangladeshi Americans
# Freebase ID: /m/04c28, Wikidata ID: Q12223, Label: Kurds
# Freebase ID: /m/03nvq, Wikidata ID: Q115473, Label: Hazaras
# Freebase ID: /m/05ztd1, Wikidata ID: Q1287427, Label: Dogra
# Freebase ID: /m/059v8, Wikidata ID: Q1123923, Label: Nez Perce

# %%
# Assign labels for ethnicity using the batch lookup dictionary
characters['actor_ethnicity_label'] = characters['actor_ethnicity'].map(
    lambda x: freebase_to_wikidata_mapping.get(x, {}).get('label', 'Unknown')
)

# Group by ethnicity and count the occurrences, excluding 'Unknown'
ethnicity_counts = characters[characters['actor_ethnicity_label'] != 'Unknown']['actor_ethnicity_label'].value_counts()

# Select the top 10 most frequent ethnicities
top_ethnicities = ethnicity_counts.head(10)

# Plotting the distribution of the top 10 ethnicities using a bar chart
plt.figure(figsize=(14, 8))
sns.barplot(x=top_ethnicities.index, y=top_ethnicities.values, palette='viridis', hue=top_ethnicities.index, legend=False)
plt.title('Top 10 Most Frequent Ethnicities in Characters Dataset', fontsize=18)
plt.xlabel('Ethnicity', fontsize=14)
plt.ylabel('Number of Actors', fontsize=14)
plt.xticks(rotation=30, ha='right', fontsize=12)
plt.yticks(fontsize=12)
sns.despine()
plt.tight_layout()
plt.show()

# %%
merged_data = pd.merge(characters, movies, on='wiki_movie_id', how='inner')
merged_data.head()
# Out:
#    wiki_movie_id free_movie_id_x   release_x actor_gender actor_ethnicity  \
# 0         975900       /m/03vyhn  2001-08-24            F         Unknown
# 1         975900       /m/03vyhn  2001-08-24            F      /m/044038p
# 2         975900       /m/03vyhn  2001-08-24            M         /m/0x67
# 3         975900       /m/03vyhn  2001-08-24            M         Unknown
# 4         975900       /m/03vyhn  2001-08-24            F         Unknown
#
#            actor_name  age_at_release free_map_id free_char_id free_actor_id  \
# 0      Wanda De Jesus            42.0  /m/0bgchxw   /m/0bgcj3x    /m/03wcfv7
# 1  Natasha Henstridge            27.0   /m/0jys3m   /m/0bgchn4     /m/0346l4
# 2            Ice Cube            32.0   /m/0jys3g   /m/0bgchn_    /m/01vw26l
# 3       Jason Statham            33.0  /m/02vchl6   /m/0bgchnq     /m/034hyc
# 4         Clea DuVall            23.0  /m/02vbb3r   /m/0bgchp9     /m/01y9xg
#
#    actor_birth_year actor_ethnicity_label free_movie_id_y      movie_name  \
# 0            1958.0               Unknown       /m/03vyhn  Ghosts of Mars
# 1            1974.0               Unknown       /m/03vyhn  Ghosts of Mars
# 2            1969.0     African Americans       /m/03vyhn  Ghosts of Mars
# 3            1967.0               Unknown       /m/03vyhn  Ghosts of Mars
# 4            1977.0               Unknown       /m/03vyhn  Ghosts of Mars
#
#    release_y  box_office                           languages  \
# 0     2001.0  14010832.0  {"/m/02h40lc": "English Language"}
# 1     2001.0  14010832.0  {"/m/02h40lc": "English Language"}
# 2     2001.0  14010832.0  {"/m/02h40lc": "English Language"}
# 3     2001.0  14010832.0  {"/m/02h40lc": "English Language"}
# 4     2001.0  14010832.0  {"/m/02h40lc": "English Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2  {"/m/09c7w0": "United States of America"}
# 3  {"/m/09c7w0": "United States of America"}
# 4  {"/m/09c7w0": "United States of America"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 2  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 4  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...

# %%
print(merged_data['movie_name'].nunique())
# Out:
# 56061

# %%
# Print the number of unique values in the 'actor_ethnicity_label' column
num_unique_ethnicities = characters['actor_ethnicity_label'].nunique()
print(f"Number of unique ethnicities in the dataset: {num_unique_ethnicities}")
# Out:
# Number of unique ethnicities in the dataset: 429
